# %%
import numpy as np
import torch
import tensorflow as tf
import gym
import sys
from collections import deque

from explorerl.utils import *
from explorerl.REINFORCE import *

# %% [markdown]
# # Reinforce CartPole

# %%
env = gym.make("CartPole-v0")
e = Env_Wrapper(env)

# %% [markdown]
# ## Without Featurizing

# %% [markdown]
# ### Tensorflow

# %%
rtf = REINFORCETf(learning_rate=0.01,featurizer=None,scaler=None)

# %%
stats = e.train(rtf,episodes=200,train_episodal=True)
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# Model Created!
# Epsilon : None, Num Steps : 199, Avg Reward with Window Size 100 : 172.3: 100%|██████████| 200/200 [04:44<00:00,  1.42s/it]
# /Users/shyam/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/shyam/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
e.test(rtf)
# Out:
# Total reward for episode 0: 200.0
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
# ...

# %% [markdown]
# ### Torch

# %%
rtorch = REINFORCETorch(learning_rate=0.01,featurizer=None,scaler=None)

# %%
stats = e.train(rtorch,episodes=250,train_episodal=True)
# Out:
# Epsilon : None, Num Steps : 58, Avg Reward with Window Size 100 : 46.5:   1%|          | 2/250 [00:00<00:23, 10.58it/s]
# Model Created!
# Epsilon : None, Num Steps : 199, Avg Reward with Window Size 100 : 183.02: 100%|██████████| 250/250 [00:46<00:00,  5.33it/s]
# /Users/shyam/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/shyam/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
e.test(rtorch)
# Out:
# Total reward for episode 0: 200.0
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
# ...
