# %%
from explorerl.utils import *
from explorerl.SARSA import *
import numpy as np
import torch
import tensorflow as tf
import gym
import sys

# %% [markdown]
# # Linear Sarsa on MountainCar

# %%
env = gym.make("MountainCar-v0")
e = Env_Wrapper(env)

# %% [markdown]
# ## With Featurizing

# %%
scaler, featurizer = create_scaler_featurizer(env,make_scaler=True)

# %% [markdown]
# ### Tensorflow

# %%
stf = SarsaTF(use_bias=True,featurizer=featurizer,scaler=scaler)

# %%
stat = e.train(stf,plot=True)
e.test(stf,gif=True)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Model Created!
# Epsilon : 3.7074446659261245e-44, Num Steps : 141, Avg Reward with Window Size 25 : -156.84: 100%|██████████| 100/100 [01:54<00:00,  1.14s/it]
# /Users/shyam/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/shyam/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Total reward for episode 0: -196.0
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
# ...

# %% [markdown]
# ### PyTorch

# %%
storch = SarsaTorch(learning_rate=0.01,
                   use_bias=True,featurizer=featurizer,scaler=scaler)

# %%
stat = e.train(storch,plot=True)
e.test(storch,gif=True)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Model Created!
# Epsilon : 3.7074446659261245e-44, Num Steps : 131, Avg Reward with Window Size 25 : -158.88: 100%|██████████| 100/100 [00:22<00:00,  4.40it/s]
# /Users/shyam/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/shyam/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Total reward for episode 0: -144.0
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
# ...

# %% [markdown]
# ## Without Featurizing

# %%
stf = SarsaTF(use_bias=True,featurizer=None,scaler=None)

# %%
stat = e.train(stf,plot=True)
e.test(stf,gif=True)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Model Created!
# Epsilon : 3.7074446659261245e-44, Num Steps : 199, Avg Reward with Window Size 25 : -200.0: 100%|██████████| 100/100 [02:30<00:00,  1.51s/it]
# /Users/shyam/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/shyam/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Total reward for episode 0: -200.0
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
# ...

# %% [markdown]
# ### PyTorch

# %%
storch = SarsaTorch(learning_rate=0.01,
                   use_bias=True,featurizer=None,scaler=None)

# %%
stat = e.train(storch,plot=True)
e.test(storch,gif=True)
# Out:
# Epsilon : 1.0, Num Steps : 199, Avg Reward with Window Size 25 : -200.0:   1%|          | 1/100 [00:00<00:16,  5.87it/s]
# Model Created!
# Epsilon : 3.7074446659261245e-44, Num Steps : 199, Avg Reward with Window Size 25 : -200.0: 100%|██████████| 100/100 [00:11<00:00,  8.49it/s]
# /Users/shyam/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/shyam/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Total reward for episode 0: -200.0
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
# ...
