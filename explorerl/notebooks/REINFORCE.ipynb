# %%
import numpy as np
import torch
import tensorflow as tf
import gym
import sys
from collections import deque

from explorerl.utils import *
from explorerl.REINFORCE import *

# %% [markdown]
# # Reinforce CartPole (Discrete)

# %%
env = gym.make("CartPole-v0")
e = EnvRunner(env)

# %% [markdown]
# ## Without Featurizing

# %% [markdown]
# ### Tensorflow

# %%
rtf = REINFORCETf(learning_rate=0.001,featurizer=None,scaler=None,replay_size=500)

# %%
stats = e.train(rtf,episodes=700,train_episodal=True)
# Out:
#   0%|          | 0/700 [00:00<?, ?it/s]
# Model Created!
# Epsilon : None, Num Steps : 199, Avg Reward with Window Size 100 : 183.0: 100%|██████████| 700/700 [09:36<00:00,  1.22it/s]
# /Users/shyam/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/shyam/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
e.test(rtf)
# Out:
# Total reward for episode 0: 200.0
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
# ...

# %% [markdown]
# ### Torch

# %%
rtorch = REINFORCETorch(learning_rate=0.001,featurizer=None,scaler=None,replay_size=500)

# %%
stats = e.train(rtorch,episodes=700,train_episodal=True)
# Out:
#   0%|          | 0/700 [00:00<?, ?it/s]
# Model Created!
# Epsilon : None, Num Steps : 130, Avg Reward with Window Size 100 : 179.52: 100%|██████████| 700/700 [00:34<00:00, 20.57it/s]
# /Users/shyam/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/shyam/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
e.test(rtorch)
# Out:
# Total reward for episode 0: 200.0
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
# ...

# %% [markdown]
# # Reinforce Lunar Lander (Discrete)

# %%
env = gym.make("LunarLander-v2")
e = EnvRunner(env)

# %% [markdown]
# ## Without Featurizing

# %% [markdown]
# ### Tensorflow

# %%
rtf = REINFORCETf(learning_rate=0.001,featurizer=None,scaler=None)

# %%
stats = e.train(rtf,episodes=2500,train_episodal=True)
# Out:
#   0%|          | 0/2500 [00:00<?, ?it/s]
# Model Created!
# Epsilon : None, Num Steps : 135, Avg Reward with Window Size 100 : -53.97025524438639:  52%|█████▏    | 1309/2500 [12:33<11:26,  1.74it/s]

# %%
e.test(rtf)

# %% [markdown]
# ### Torch

# %%
rtorch = REINFORCETorch(learning_rate=0.001,featurizer=None,scaler=None)

# %%
stats = e.train(rtorch,episodes=2500,train_episodal=True)

# %%
e.test(rtorch)
