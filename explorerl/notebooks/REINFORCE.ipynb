# %%
import numpy as np
import torch
import tensorflow as tf
import gym
import sys
from collections import deque

from explorerl.utils import *
from explorerl.REINFORCE import *

# %% [markdown]
# # Reinforce CartPole (Discrete)

# %%
env = gym.make("CartPole-v0")
e = EnvRunner(env)

# %% [markdown]
# ## Without Featurizing

# %% [markdown]
# ### Tensorflow

# %%
rtf = REINFORCETf(learning_rate=0.01,featurizer=None,scaler=None,replay_size=500)

# %%
stats = e.train(rtf,episodes=200,train_episodal=True)
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# Model Created!
# Epsilon : None, Num Steps : 152, Avg Reward with Window Size 100 : 118.7: 100%|██████████| 200/200 [01:13<00:00,  2.71it/s]
# /Users/shyam/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/shyam/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
e.test(rtf)
# Out:
# Total reward for episode 0: 42.0
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgRQWIYRCXQJBQTZGV">
#     <br>
#     <input id="_anim_sliderRQWIYRCXQJBQTZGV" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animRQWIYRCXQJBQTZGV.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animRQWIYRCXQJBQTZGV.slower()">&#8211;</button>
#     <button onclick="animRQWIYRCXQJBQTZGV.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animRQWIYRCXQJBQTZGV.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animRQWIYRCXQJBQTZGV.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animRQWIYRCXQJBQTZGV.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animRQWIYRCXQJBQTZGV.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animRQWIYRCXQJBQTZGV.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animRQWIYRCXQJBQTZGV.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animRQWIYRCXQJBQTZGV.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectRQWIYRCXQJBQTZGV" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgRQWIYRCXQJBQTZGV";
#     var slider_id = "_anim_sliderRQWIYRCXQJBQTZGV";
#     var loop_select_id = "_anim_loop_selectRQWIYRCXQJBQTZGV";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#   frames[20] = "data:image/png;base64,..."
#   frames[21] = "data:image/png;base64,..."
#   frames[22] = "data:image/png;base64,..."
#   frames[23] = "data:image/png;base64,..."
#   frames[24] = "data:image/png;base64,..."
#   frames[25] = "data:image/png;base64,..."
#   frames[26] = "data:image/png;base64,..."
#   frames[27] = "data:image/png;base64,..."
#   frames[28] = "data:image/png;base64,..."
#   frames[29] = "data:image/png;base64,..."
#   frames[30] = "data:image/png;base64,..."
#   frames[31] = "data:image/png;base64,..."
#   frames[32] = "data:image/png;base64,..."
#   frames[33] = "data:image/png;base64,..."
#   frames[34] = "data:image/png;base64,..."
#   frames[35] = "data:image/png;base64,..."
#   frames[36] = "data:image/png;base64,..."
#   frames[37] = "data:image/png;base64,..."
#   frames[38] = "data:image/png;base64,..."
#   frames[39] = "data:image/png;base64,..."
#   frames[40] = "data:image/png;base64,..."
#   frames[41] = "data:image/png;base64,..."
#
#
#     /* set a timeout to make sure all the above elements are created before
#        the object is initialized. */
#     setTimeout(function() {
#         animRQWIYRCXQJBQTZGV = new Animation(frames, img_id, slider_id, 50, loop_select_id);
#     }, 0);
#   })()
# </script>

# %% [markdown]
# ### Torch

# %%
rtorch = REINFORCETorch(learning_rate=0.001,featurizer=None,scaler=None,replay_size=500)

# %%
stats = e.train(rtorch,episodes=200,train_episodal=True)
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# Model Created!
# Epsilon : None, Num Steps : 43, Avg Reward with Window Size 100 : 52.24: 100%|██████████| 200/200 [00:06<00:00, 31.73it/s]
# /Users/shyam/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/shyam/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
e.test(rtorch)
# Out:
# Total reward for episode 0: 66.0
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgRMGSDATHEOGEHMYC">
#     <br>
#     <input id="_anim_sliderRMGSDATHEOGEHMYC" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animRMGSDATHEOGEHMYC.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animRMGSDATHEOGEHMYC.slower()">&#8211;</button>
#     <button onclick="animRMGSDATHEOGEHMYC.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animRMGSDATHEOGEHMYC.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animRMGSDATHEOGEHMYC.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animRMGSDATHEOGEHMYC.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animRMGSDATHEOGEHMYC.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animRMGSDATHEOGEHMYC.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animRMGSDATHEOGEHMYC.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animRMGSDATHEOGEHMYC.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectRMGSDATHEOGEHMYC" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgRMGSDATHEOGEHMYC";
#     var slider_id = "_anim_sliderRMGSDATHEOGEHMYC";
#     var loop_select_id = "_anim_loop_selectRMGSDATHEOGEHMYC";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#   frames[20] = "data:image/png;base64,..."
#   frames[21] = "data:image/png;base64,..."
#   frames[22] = "data:image/png;base64,..."
#   frames[23] = "data:image/png;base64,..."
#   frames[24] = "data:image/png;base64,..."
#   frames[25] = "data:image/png;base64,..."
#   frames[26] = "data:image/png;base64,..."
#   frames[27] = "data:image/png;base64,..."
#   frames[28] = "data:image/png;base64,..."
#   frames[29] = "data:image/png;base64,..."
#   frames[30] = "data:image/png;base64,..."
#   frames[31] = "data:image/png;base64,..."
#   frames[32] = "data:image/png;base64,..."
#   frames[33] = "data:image/png;base64,..."
#   frames[34] = "data:image/png;base64,..."
#   frames[35] = "data:image/png;base64,..."
#   frames[36] = "data:image/png;base64,..."
#   frames[37] = "data:image/png;base64,..."
#   frames[38] = "data:image/png;base64,..."
#   frames[39] = "data:image/png;base64,..."
#   frames[40] = "data:image/png;base64,..."
#   frames[41] = "data:image/png;base64,..."
#   frames[42] = "data:image/png;base64,..."
#   frames[43] = "data:image/png;base64,..."
#   frames[44] = "data:image/png;base64,..."
#   frames[45] = "data:image/png;base64,..."
#   frames[46] = "data:image/png;base64,..."
#   frames[47] = "data:image/png;base64,..."
#   frames[48] = "data:image/png;base64,..."
#   frames[49] = "data:image/png;base64,..."
#   frames[50] = "data:image/png;base64,..."
#   frames[51] = "data:image/png;base64,..."
#   frames[52] = "data:image/png;base64,..."
#   frames[53] = "data:image/png;base64,..."
#   frames[54] = "data:image/png;base64,..."
#   frames[55] = "data:image/png;base64,..."
#   frames[56] = "data:image/png;base64,..."
#   frames[57] = "data:image/png;base6

# %% [markdown]
# # Reinforce Lunar Lander (Discrete)

# %%
env = gym.make("LunarLander-v2")
e = EnvRunner(env)

# %% [markdown]
# ## Without Featurizing

# %% [markdown]
# ### Tensorflow

# %%
rtf = REINFORCETf(learning_rate=0.001,featurizer=None,scaler=None)

# %%
stats = e.train(rtf,episodes=2500,train_episodal=True)
# Out:
#   0%|          | 0/2500 [00:00<?, ?it/s]
# Model Created!
# Epsilon : None, Num Steps : 89, Avg Reward with Window Size 100 : -239.3214269939979:   1%|▏         | 33/2500 [00:16<20:38,  1.99it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-0632d2cf602d> in <module>()
# ----> 1 stats = e.train(rtf,episodes=2500,train_episodal=True)
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/explorerl-0.0.1-py3.6.egg/explorerl/utils/EnvRunner.py in train(self, agent, episodes, max_len, description_configs, early_stop, stop_criteria, plot, train_episodal)
#      30                 action = values[0]
#      31                 next_obs, reward, done, info = self.env.step(action)
# ---> 32                 next_obs = agent.featurize_state(next_obs)
#      33                 agent.save_replay(observation,action,next_obs,reward,done)
#      34                 if train_episodal == False:
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/explorerl-0.0.1-py3.6.egg/explorerl/agents/BaseTfAgent.py in featurize_state(self, state)
#      43             return featurized
#      44         if len(state.shape) == 1:
# ---> 45             return np.expand_dims(state,0)
#      46         return state
#      47
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/lib/shape_base.py in expand_dims(a, axis)
#     571
#     572     """
# --> 573     if isinstance(a, matrix):
#     574         a = asarray(a)
#     575     else:
#
# KeyboardInterrupt:

# %%
e.test(rtf)

# %% [markdown]
# ### Torch

# %%
rtorch = REINFORCETorch(learning_rate=0.0001,featurizer=None,scaler=None)

# %%
stats = e.train(rtorch,episodes=100,train_episodal=True)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Model Created!
# Epsilon : None, Num Steps : 86, Avg Reward with Window Size 100 : -242.18141029089952:   0%|          | 0/100 [00:00<?, ?it/s]
# Epsilon : None, Num Steps : 86, Avg Reward with Window Size 100 : -242.18141029089952:   1%|          | 1/100 [00:00<00:36,  2.71it/s]
# Epsilon : None, Num Steps : 68, Avg Reward with Window Size 100 : -175.50100954201338:   1%|          | 1/100 [00:00<00:42,  2.31it/s]
# Epsilon : None, Num Steps : 77, Avg Reward with Window Size 100 : -158.53624970314146:   1%|          | 1/100 [00:00<00:48,  2.03it/s]
# Epsilon : None, Num Steps : 77, Avg Reward with Window Size 100 : -158.53624970314146:   3%|▎         | 3/100 [00:00<00:16,  6.06it/s]
# Epsilon : None, Num Steps : 108, Avg Reward with Window Size 100 : -171.75516643553922:   3%|▎         | 3/100 [00:00<00:18,  5.18it/s]
# Epsilon : None, Num Steps : 87, Avg Reward with Window Size 100 : -165.78923333196514:   3%|▎         | 3/100 [00:00<00:20,  4.63it/s]
# Epsilon : None, Num Steps : 87, Avg Reward with Window Size 100 : -165.78923333196514:   5%|▌         | 5/100 [00:00<00:12,  7.70it/s]
# Epsilon : None, Num Steps : 99, Avg Reward with Window Size 100 : -171.46538368485656:   5%|▌         | 5/100 [00:00<00:14,  6.68it/s]
# Epsilon : None, Num Steps : 99, Avg Reward with Window Size 100 : -171.46538368485656:   6%|▌         | 6/100 [00:00<00:11,  7.99it/s]
# Epsilon : None, Num Steps : 92, Avg Reward with Window Size 100 : -166.3271110681401:   6%|▌         | 6/100 [00:00<00:13,  7.13it/s]
# Epsilon : None, Num Steps : 107, Avg Reward with Window Size 100 : -150.8834635225794:   6%|▌         | 6/100 [00:00<00:14,  6.47it/s]
# Epsilon : None, Num Steps : 107, Avg Reward with Window Size 100 : -150.8834635225794:   8%|▊         | 8/100 [00:00<00:10,  8.59it/s]
# Epsilon : None, Num Steps : 82, Avg Reward with Window Size 100 : -155.63952648792386:   8%|▊         | 8/100 [00:00<00:11,  8.04it/s]
# Epsilon : None, Num Steps : 87, Avg Reward with Window Size 100 : -175.72434875943338:   8%|▊         | 8/100 [00:01<00:12,  7.49it/s]
# Epsilon : None, Num Steps : 87, Avg Reward with Window Size 100 : -175.72434875943338:  10%|█         | 10/100 [00:01<00:09,  9.33it/s]
# Epsilon : None, Num Steps : 68, Avg Reward with Window Size 100 : -170.33794183194848:  10%|█         | 10/100 [00:01<00:10,  8.81it/s]
# Epsilon : None, Num Steps : 84, Avg Reward with Window Size 100 : -171.98901385132626:  10%|█         | 10/100 [00:01<00:10,  8.29it/s]
# Epsilon : None, Num Steps : 84, Avg Reward with Window Size 100 : -171.98901385132626:  12%|█▏        | 12/100 [00:01<00:08,  9.93it/s]
# Epsilon : None, Num Steps : 78, Avg Reward with Window Size 100 : -180.94567696882754:  12%|█▏        | 12/100 [00:01<00:09,  9.30it/s]
# Epsilon : None, Num Steps : 101, Avg Reward with Window Size 100 : -176.48196507182834:  12%|█▏        | 12/100 [00:01<00:10,  8.76it/s]
# Epsilon : None, Num Steps : 101, Avg Reward with Window Size 100 : -176.48196507182834:  14%|█▍        | 14/100 [00:01<00:08, 10.20it/s]
# Epsilon : None, Num Steps : 110, Avg Reward with Window Size 100 : -178.67488898173633:  14%|█▍        | 14/100 [00:01<00:09,  9.50it/s]
# Epsilon : None, Num Steps : 71, Avg Reward with Window Size 100 : -176.1244321338425:  14%|█▍        | 14/100 [00:01<00:09,  9.10it/s]
# Epsilon : None, Num Steps : 71, Avg Reward with Window Size 100 : -176.1244321338425:  16%|█▌        | 16/100 [00:01<00:08, 10.38it/s]
# Epsilon : None, Num Steps : 87, Avg Reward with Window Size 100 : -175.54147312661334:  16%|█▌        | 16/100 [00:01<00:08,  9.87it/s]
# Epsilon : None, Num Steps : 65, Avg Reward with Window Size 100 : -175.42858281966312:  16%|█▌        | 16/100 [00:01<00:08,  9.47it/s]
# Epsilon : None, Num Steps : 65, Avg Reward with Window Size 100 : -175.42858281966312:  18%|█▊        | 18/100 [00:01<00:07, 10.64it/s]
# Epsilon : None, Num Steps : 73, Avg Reward with Window Size 100 : -174.37026154047285:  18%|█▊        | 18/100 [00:01<00:08, 10.24it/s]
# Epsilon : None, Num Steps : 97, Avg Reward with Window Size 100 : -185.43131486185538:  18%|█▊        | 18/100 [00:01<00:08,  9.78it/s]
# Epsilon : None, Num Steps : 97, Avg Reward with Window Size 100 : -185.43131486185538:  20%|██        | 20/100 [00:01<00:07, 10.85it/s]
# Epsilon : None, Num Steps : 73, Avg Reward with Window Size 100 : -181.47083293532657:  20%|██        | 20/100 [00:01<00:07, 10.45it/s]
# Epsilon : None, Num Steps : 95, Avg Reward with Window Size 100 : -192.76516617685874:  20%|██        | 20/100 [00:01<00:07, 10.02it/s]
# Epsilon : None, Num Steps : 95, Avg Reward with Window Size 100 : -192.76516617685874:  22%|██▏       | 22/100 [00:01<00:07, 11.01it/s]
# Epsilon : None, Num Steps : 61, Avg Reward with Window Size 100 : -189.47148520426964:  22%|██▏       | 22/100 [00:02<00:07, 10.69it/s]
# Epsilon : None, Num Steps : 86, Avg Reward with Window Size 100 : -185.9794675346981:  22%|██▏       | 22/100 [00:02<00:07, 10.28it/s]
# Epsilon : None, Num Steps : 86, Avg Reward with Window Size 100 : -185.9794675346981:  24%|██▍       | 24/100 [00:02<00:06, 11.20it/s]
# Epsilon : None, Num Steps : 66, Avg Reward with Window Size 100 : -187.61236818157198:  24%|██▍       | 24/100 [00:02<00:07, 10.80it/s]
# Epsilon : None, Num Steps : 91, Avg Reward with Window Size 100 : -184.847361864334:  24%|██▍       | 24/100 [00:02<00:07, 10.28it/s]
# Epsilon : None, Num Steps : 91, Avg Reward with Window Size 100 : -184.847361864334:  26%|██▌       | 26/100 [00:02<00:06, 11.12it/s]
# Epsilon : None, Num Steps : 87, Avg Reward with Window Size 100 : -181.80316558137062:  26%|██▌       | 26/100 [00:02<00:06, 10.71it/s]
# Epsilon : None, Num Steps : 105, Avg Reward with Window Size 100 : -179.220234337378:  26%|██▌       | 26/100 [00:02<00:07, 10.33it/s]
# Epsilon : None, Num Steps : 105, Avg Reward with Window Size 100 : -179.220234337378:  28%|██▊       | 28/100 [00:02<00:06, 11.12it/s]
# Epsilon : None, Num Steps : 93, Avg Reward with Window Size 100 : -177.93945120517395:  28%|██▊       | 28/100 [00:02<00:06, 10.79it/s]
# Epsilon : None, Num Steps : 55, Avg Reward with Window Size 100 : -174.88349505007315:  28%|██▊       | 28/100 [00:02<00:06, 10.58it/s]
# Epsilon : None, Num Steps : 55, Avg Reward with Window Size 100 : -174.88349505007315:  30%|███       | 30/100 [00:02<00:06, 11.31it/s]
# Epsilon : None, Num Steps : 96, Avg Reward with Window Size 100 : -175.84890704622404:  30%|███       | 30/100 [00:02<00:06, 10.96it/s]
# Epsilon : None, Num Steps : 88, Avg Reward with Window Size 100 : -175.75461755460003:  30%|███       | 30/100 [00:02<00:06, 10.52it/s]
# Epsilon : None, Num Steps : 88, Avg Reward with Window Size 100 : -175.75461755460003:  32%|███▏      | 32/100 [00:02<00:06, 11.21it/s]
# Epsilon : None, Num Steps : 87, Avg Reward with Window Size 100 : -184.8525938210788:  32%|███▏      | 32/100 [00:02<00:06, 10.79it/s]
# Epsilon : None, Num Steps : 88, Avg Reward with Window Size 100 : -193.03931117587643:  32%|███▏      | 32/100 [00:03<00:06, 10.49it/s]
# Epsilon : None, Num Steps : 88, Avg Reward with Window Size 100 : -193.03931117587643:  34%|███▍      | 34/100 [00:03<00:05, 11.14it/s]
# Epsilon : None, Num Steps : 111, Avg Reward with Window Size 100 : -188.7971820200586:  34%|███▍      | 34/100 [00:03<00:06, 10.75it/s]
# Epsilon : None, Num Steps : 112, Avg Reward with Window Size 100 : -197.858486598096:  34%|███▍      | 34/100 [00:03<00:06, 10.43it/s]
# Epsilon : None, Num Steps : 112, Avg Reward with Window Size 100 : -197.858486598096:  36%|███▌      | 36/100 [00:03<00:05, 11.04it/s]
# Epsilon : None, Num Steps : 93, Avg Reward with Window Size 100 : -193.82579007016463:  36%|███▌      | 36/100 [00:03<00:05, 10.72it/s]
# Epsilon : None, Num Steps : 68, Avg Reward with Window Size 100 : -192.94194854687575:  36%|███▌      | 36/100 [00:03<00:06, 10.52it/s]
# Epsilon : None, Num Steps : 68, Avg Reward with Window Size 100 : -192.94194854687575:  38%|███▊      | 38/100 [00:03<00:05, 11.09it/s]
# Epsilon : None, Num Steps : 105, Avg Reward with Window Size 100 : -196.94407670760117:  38%|███▊      | 38/100 [00:03<00:05, 10.78it/s]
# Epsilon : None, Num Steps : 74, Avg Reward with Window Size 100 : -195.46892660369866:  38%|███▊      | 38/100 [00:03<00:05, 10.58it/s]
# Epsilon : None, Num Steps : 74, Avg Reward with Window Size 100 : -195.46892660369866:  40%|████      | 40/100 [00:03<00:05, 11.13it/s]
# Epsilon : None, Num Steps : 97, Avg Reward with Window Size 100 : -193.83366372094736:  40%|████      | 40/100 [00:03<00:05, 10.72it/s]
# Epsilon : None, Num Steps : 105, Avg Reward with Window Size 100 : -194.47208823897145:  40%|████      | 40/100 [00:03<00:05, 10.38it/s]
# Epsilon : None, Num Steps : 105, Avg Reward with Window Size 100 : -194.47208823897145:  42%|████▏     | 42/100 [00:03<00:05, 10.89it/s]
# Epsilon : None, Num Steps : 75, Avg Reward with Window Size 100 : -192.44760234001947:  42%|████▏     | 42/100 [00:03<00:05, 10.67it/s]
# Epsilon : None, Num Steps : 115, Avg Reward with Window Size 100 : -191.29460962890116:  42%|████▏     | 42/100 [00:04<00:05, 10.41it/s]
# Epsilon : None, Num Steps : 115, Avg Reward with Window Size 100 : -191.29460962890116:  44%|████▍     | 44/100 [00:04<00:05, 10.90it/s]
# Epsilon : None, Num Steps : 66, Avg Reward with Window Size 100 : -188.58979778853654:  44%|████▍     | 44/100 [00:04<00:05, 10.73it/s]
# Epsilon : None, Num Steps : 66, Avg Reward with Window Size 100 : -186.60183502707747:  44%|████▍     | 44/100 [00:04<00:05, 10.58it/s]
# Epsilon : None, Num Steps : 66, Avg Reward with Window Size 100 : -186.60183502707747:  46%|████▌     | 46/100 [00:04<00:04, 11.05it/s]
# Epsilon : None, Num Steps : 87, Avg Reward with Window Size 100 : -190.45674180863344:  46%|████▌     | 46/100 [00:04<00:04, 10.82it/s]
# Epsilon : None, Num Steps : 69, Avg Reward with Window Size 100 : -188.71436631524398:  46%|████▌     | 46/100 [00:04<00:05, 10.67it/s]
# Epsilon : None, Num Steps : 69, Avg Reward with Window Size 100 : -188.71436631524398:  48%|████▊     | 48/100 [00:04<00:04, 11.13it/s]
# Epsilon : None, Num Steps : 120, Avg Reward with Window Size 100 : -187.70010291874632:  48%|████▊     | 48/100 [00:04<00:04, 10.85it/s]
# Epsilon : None, Num Steps : 88, Avg Reward with Window Size 100 : -187.0304548910568:  48%|████▊     | 48/100 [00:04<00:04, 10.66it/s]
# Epsilon : None, Num Steps : 88, Avg Reward with Window Size 100 : -187.0304548910568:  50%|█████     | 50/100 [00:04<00:04, 11.10it/s]
# Epsilon : None, Num Steps : 80, Avg Reward with Window Size 100 : -188.3546671993681:  50%|█████     | 50/100 [00:04<00:04, 10.92it/s]
# Epsilon : None, Num Steps : 116, Avg Reward with Window Size 100 : -186.60808619019843:  50%|█████     | 50/100 [00:04<00:04, 10.64it/s]
# Epsilon : None, Num Steps : 116, Avg Reward with Window Size 100 : -186.60808619019843:  52%|█████▏    | 52/100 [00:04<00:04, 11.06it/s]
# Epsilon : None, Num Steps : 116, Avg Reward with Window Size 100 : -184.67021249896754:  52%|█████▏    | 52/100 [00:04<00:04, 10.71it/s]
# Epsilon : None, Num Steps : 74, Avg Reward with Window Size 100 : -183.11521655525843:  52%|█████▏    | 52/100 [00:04<00:04, 10.58it/s]
# Epsilon : None, Num Steps : 74, Avg Reward with Window Size 100 : -183.11521655525843:  54%|█████▍    | 54/100 [00:04<00:04, 10.98it/s]
# Epsilon : None, Num Steps : 85, Avg Reward with Window Size 100 : -181.66963282437607:  54%|█████▍    | 54/100 [00:04<00:04, 10.81it/s]
# Epsilon : None, Num Steps : 102, Avg Reward with Window Size 100 : -180.35704371071316:  54%|█████▍    | 54/100 [00:05<00:04, 10.60it/s]
# Epsilon : None, Num Steps : 102, Avg Reward with Window Size 100 : -180.35704371071316:  56%|█████▌    | 56/100 [00:05<00:04, 10.98it/s]
# Epsilon : None, Num Steps : 95, Avg Reward with Window Size 100 : -179.17449756502688:  56%|█████▌    | 56/100 [00:05<00:04, 10.79it/s]
# Epsilon : None, Num Steps : 76, Avg Reward with Window Size 100 : -180.6331054869013:  56%|█████▌    | 56/100 [00:05<00:04, 10.65it/s]
# Epsilon : None, Num Steps : 76, Avg Reward with Window Size 100 : -180.6331054869013:  58%|█████▊    | 58/100 [00:05<00:03, 11.02it/s]
# Epsilon : None, Num Steps : 65, Avg Reward with Window Size 100 : -182.16837046510096:  58%|█████▊    | 58/100 [00:05<00:03, 10.87it/s]
# Epsilon : None, Num Steps : 63, Avg Reward with Window Size 100 : -181.0788907925361:  58%|█████▊    | 58/100 [00:05<00:03, 10.74it/s]
# Epsilon : None, Num Steps : 63, Avg Reward with Window Size 100 : -181.0788907925361:  60%|██████    | 60/100 [00:05<00:03, 11.10it/s]
# Epsilon : None, Num Steps : 90, Avg Reward with Window Size 100 : -180.4253131322565:  60%|██████    | 60/100 [00:05<00:03, 10.89it/s]
# Epsilon : None, Num Steps : 70, Avg Reward with Window Size 100 : -179.341117290409:  60%|██████    | 60/100 [00:05<00:03, 10.74it/s]
# Epsilon : None, Num Steps : 70, Avg Reward with Window Size 100 : -179.341117290409:  62%|██████▏   | 62/100 [00:05<00:03, 11.08it/s]
# Epsilon : None, Num Steps : 69, Avg Reward with Window Size 100 : -178.09099624193456:  62%|██████▏   | 62/100 [00:05<00:03, 10.91it/s]
# Epsilon : None, Num Steps : 68, Avg Reward with Window Size 100 : -176.8360992161518:  62%|██████▏   | 62/100 [00:05<00:03, 10.77it/s]
# Epsilon : None, Num Steps : 68, Avg Reward with Window Size 100 : -176.8360992161518:  64%|██████▍   | 64/100 [00:05<00:03, 11.11it/s]
# Epsilon : None, Num Steps : 76, Avg Reward with Window Size 100 : -176.95935282081317:  64%|██████▍   | 64/100 [00:05<00:03, 10.91it/s]
# Epsilon : None, Num Steps : 119, Avg Reward with Window Size 100 : -177.21794800345606:  64%|██████▍   | 64/100 [00:05<00:03, 10.67it/s]
# Epsilon : None, Num Steps : 119, Avg Reward with Window Size 100 : -177.21794800345606:  66%|██████▌   | 66/100 [00:06<00:03, 11.00it/s]
# Epsilon : None, Num Steps : 67, Avg Reward with Window Size 100 : -176.3852585541855:  66%|██████▌   | 66/100 [00:06<00:03, 10.86it/s]
# Epsilon : None, Num Steps : 69, Avg Reward with Window Size 100 : -175.94944099015888:  66%|██████▌   | 66/100 [00:06<00:03, 10.74it/s]
# Epsilon : None, Num Steps : 69, Avg Reward with Window Size 100 : -175.94944099015888:  68%|██████▊   | 68/100 [00:06<00:02, 11.06it/s]
# Epsilon : None, Num Steps : 108, Avg Reward with Window Size 100 : -177.25373732740624:  68%|██████▊   | 68/100 [00:06<00:02, 10.87it/s]
# Epsilon : None, Num Steps : 59, Avg Reward with Window Size 100 : -175.55015401250358:  68%|██████▊   | 68/100 [00:06<00:02, 10.75it/s]
# Epsilon : None, Num Steps : 59, Avg Reward with Window Size 100 : -175.55015401250358:  70%|███████   | 70/100 [00:06<00:02, 11.05it/s]
# Epsilon : None, Num Steps : 109, Avg Reward with Window Size 100 : -174.22266640871564:  70%|███████   | 70/100 [00:06<00:02, 10.84it/s]
# Epsilon : None, Num Steps : 71, Avg Reward with Window Size 100 : -173.26931333670038:  70%|███████   | 70/100 [00:06<00:02, 10.73it/s]
# Epsilon : None, Num Steps : 71, Avg Reward with Window Size 100 : -173.26931333670038:  72%|███████▏  | 72/100 [00:06<00:02, 11.03it/s]
# Epsilon : None, Num Steps : 73, Avg Reward with Window Size 100 : -172.83254380991784:  72%|███████▏  | 72/100 [00:06<00:02, 10.90it/s]
# Epsilon : None, Num Steps : 81, Avg Reward with Window Size 100 : -171.76242637716274:  72%|███████▏  | 72/100 [00:06<00:02, 10.77it/s]
# Epsilon : None, Num Steps : 81, Avg Reward with Window Size 100 : -171.76242637716274:  74%|███████▍  | 74/100 [00:06<00:02, 11.06it/s]
# Epsilon : None, Num Steps : 57, Avg Reward with Window Size 100 : -170.92973253673628:  74%|███████▍  | 74/100 [00:06<00:02, 10.97it/s]
# Epsilon : None, Num Steps : 94, Avg Reward with Window Size 100 : -168.54129772624773:  74%|███████▍  | 74/100 [00:06<00:02, 10.83it/s]
# Epsilon : None, Num Steps : 94, Avg Reward with Window Size 100 : -168.54129772624773:  76%|███████▌  | 76/100 [00:06<00:02, 11.12it/s]
# Epsilon : None, Num Steps : 85, Avg Reward with Window Size 100 : -168.14154224822963:  76%|███████▌  | 76/100 [00:06<00:02, 10.99it/s]
# Epsilon : None, Num Steps : 64, Avg Reward with Window Size 100 : -167.5347866926597:  76%|███████▌  | 76/100 [00:06<00:02, 10.91it/s]
# Epsilon : None, Num Steps : 64, Avg Reward with Window Size 100 : -167.5347866926597:  78%|███████▊  | 78/100 [00:06<00:01, 11.19it/s]
# Epsilon : None, Num Steps : 63, Avg Reward with Window Size 100 : -167.27456873520228:  78%|███████▊  | 78/100 [00:07<00:01, 11.08it/s]
# Epsilon : None, Num Steps : 111, Avg Reward with Window Size 100 : -166.55842937859285:  78%|███████▊  | 78/100 [00:07<00:02, 10.93it/s]
# Epsilon : None, Num Steps : 111, Avg Reward with Window Size 100 : -166.55842937859285:  80%|████████  | 80/100 [00:07<00:01, 11.20it/s]
# Epsilon : None, Num Steps : 94, Avg Reward with Window Size 100 : -167.80387493676727:  80%|████████  | 80/100 [00:07<00:01, 11.04it/s]
# Epsilon : None, Num Steps : 124, Avg Reward with Window Size 100 : -168.35956179170614:  80%|████████  | 80/100 [00:07<00:01, 10.89it/s]
# Epsilon : None, Num Steps : 124, Avg Reward with Window Size 100 : -168.35956179170614:  82%|████████▏ | 82/100 [00:07<00:01, 11.15it/s]
# Epsilon : None, Num Steps : 92, Avg Reward with Window Size 100 : -168.3596786581463:  82%|████████▏ | 82/100 [00:07<00:01, 11.03it/s]
# Epsilon : None, Num Steps : 71, Avg Reward with Window Size 100 : -168.4723149247217:  82%|████████▏ | 82/100 [00:07<00:01, 10.93it/s]
# Epsilon : None, Num Steps : 71, Avg Reward with Window Size 100 : -168.4723149247217:  84%|████████▍ | 84/100 [00:07<00:01, 11.20it/s]
# Epsilon : None, Num Steps : 64, Avg Reward with Window Size 100 : -167.84490680462758:  84%|████████▍ | 84/100 [00:07<00:01, 11.09it/s]
# Epsilon : None, Num Steps : 88, Avg Reward with Window Size 100 : -171.7384236339881:  84%|████████▍ | 84/100 [00:07<00:01, 10.97it/s]
# Epsilon : None, Num Steps : 88, Avg Reward with Window Size 100 : -171.7384236339881:  86%|████████▌ | 86/100 [00:07<00:01, 11.22it/s]
# Epsilon : None, Num Steps : 79, Avg Reward with Window Size 100 : -174.39773663568866:  86%|████████▌ | 86/100 [00:07<00:01, 11.08it/s]
# Epsilon : None, Num Steps : 68, Avg Reward with Window Size 100 : -173.10637893016005:  86%|████████▌ | 86/100 [00:07<00:01, 10.98it/s]
# Epsilon : None, Num Steps : 68, Avg Reward with Window Size 100 : -173.10637893016005:  88%|████████▊ | 88/100 [00:07<00:01, 11.23it/s]
# Epsilon : None, Num Steps : 76, Avg Reward with Window Size 100 : -172.4679643229202:  88%|████████▊ | 88/100 [00:07<00:01, 11.13it/s]
# Epsilon : None, Num Steps : 88, Avg Reward with Window Size 100 : -175.5219739695388:  88%|████████▊ | 88/100 [00:07<00:01, 11.03it/s]
# Epsilon : None, Num Steps : 88, Avg Reward with Window Size 100 : -175.5219739695388:  90%|█████████ | 90/100 [00:07<00:00, 11.27it/s]
# Epsilon : None, Num Steps : 79, Avg Reward with Window Size 100 : -174.9150085862698:  90%|█████████ | 90/100 [00:08<00:00, 11.16it/s]
# Epsilon : None, Num Steps : 63, Avg Reward with Window Size 100 : -175.27055355605393:  90%|█████████ | 90/100 [00:08<00:00, 11.09it/s]
# Epsilon : None, Num Steps : 63, Avg Reward with Window Size 100 : -175.27055355605393:  92%|█████████▏| 92/100 [00:08<00:00, 11.33it/s]
# Epsilon : None, Num Steps : 101, Avg Reward with Window Size 100 : -175.09411914792298:  92%|█████████▏| 92/100 [00:08<00:00, 11.21it/s]
# Epsilon : None, Num Steps : 72, Avg Reward with Window Size 100 : -174.22868042930287:  92%|█████████▏| 92/100 [00:08<00:00, 11.12it/s]
# Epsilon : None, Num Steps : 72, Avg Reward with Window Size 100 : -174.22868042930287:  94%|█████████▍| 94/100 [00:08<00:00, 11.35it/s]
# Epsilon : None, Num Steps : 87, Avg Reward with Window Size 100 : -173.6671550358412:  94%|█████████▍| 94/100 [00:08<00:00, 11.23it/s]
# Epsilon : None, Num Steps : 85, Avg Reward with Window Size 100 : -173.3186115780796:  94%|█████████▍| 94/100 [00:08<00:00, 11.14it/s]
# Epsilon : None, Num Steps : 85, Avg Reward with Window Size 100 : -173.3186115780796:  96%|█████████▌| 96/100 [00:08<00:00, 11.37it/s]
# Epsilon : None, Num Steps : 97, Avg Reward with Window Size 100 : -173.38636865060587:  96%|█████████▌| 96/100 [00:08<00:00, 11.25it/s]
# Epsilon : None, Num Steps : 72, Avg Reward with Window Size 100 : -173.96562577229705:  96%|█████████▌| 96/100 [00:08<00:00, 11.16it/s]
# Epsilon : None, Num Steps : 72, Avg Reward with Window Size 100 : -173.96562577229705:  98%|█████████▊| 98/100 [00:08<00:00, 11.39it/s]
# Epsilon : None, Num Steps : 85, Avg Reward with Window Size 100 : -172.34785552610188:  98%|█████████▊| 98/100 [00:08<00:00, 11.28it/s]
# Epsilon : None, Num Steps : 70, Avg Reward with Window Size 100 : -171.68366460142408:  98%|█████████▊| 98/100 [00:08<00:00, 11.20it/s]
# Epsilon : None, Num Steps : 70, Avg Reward with Window Size 100 : -171.68366460142408: 100%|██████████| 100/100 [00:08<00:00, 11.42it/s]
# /Users/shyam/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/shyam/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
e.test(rtorch)
# Out:
# Total reward for episode 0: -429.5909955171548
