# %%
import numpy as np
import torch
import tensorflow as tf
import gym
import sys
from collections import deque

from explorerl.utils import *
from explorerl.REINFORCE import *

# %% [markdown]
# # Reinforce CartPole (Discrete)

# %%
env = gym.make("CartPole-v0")
e = EnvRunner(env)

# %% [markdown]
# ## Without Featurizing

# %% [markdown]
# ### Tensorflow

# %%
rtf = REINFORCETf(learning_rate=0.01,featurizer=None,scaler=None,replay_size=500)

# %%
stats = e.train(rtf,episodes=100,train_episodal=True)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Model Created!
# Epsilon : None, Num Steps : 199, Avg Reward with Window Size 100 : 72.36: 100%|██████████| 100/100 [00:41<00:00,  2.41it/s]
# /Users/shyam/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/shyam/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
e.test(rtf)
# Out:
# Total reward for episode 0: 108.0
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
# ...

# %% [markdown]
# ### Torch

# %%
rtorch = REINFORCETorch(learning_rate=0.01,featurizer=None,scaler=None,replay_size=500)

# %%
stats = e.train(rtorch,episodes=200,train_episodal=True)
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# Model Created!
# Epsilon : None, Num Steps : 107, Avg Reward with Window Size 100 : 173.04: 100%|██████████| 200/200 [00:20<00:00,  9.84it/s]
# /home/ssudhakaran/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/ssudhakaran/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
e.test(rtorch)
# Out:
# Total reward for episode 0: 200.0
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
# ...

# %% [markdown]
# # Reinforce Lunar Lander (Discrete)

# %%
env = gym.make("LunarLander-v2")
e = EnvRunner(env)

# %% [markdown]
# ## Without Featurizing

# %% [markdown]
# ### Tensorflow

# %%
rtf = REINFORCETf(learning_rate=0.001,featurizer=None,scaler=None)

# %%
stats = e.train(rtf,episodes=2500,train_episodal=True)
# Out:
#   0%|          | 0/2500 [00:00<?, ?it/s]
# Model Created!
# Epsilon : None, Num Steps : 74, Avg Reward with Window Size 100 : -239.60084800858635:  13%|█▎        | 327/2500 [02:42<18:02,  2.01it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-0632d2cf602d> in <module>()
# ----> 1 stats = e.train(rtf,episodes=2500,train_episodal=True)
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/explorerl-0.0.1-py3.6.egg/explorerl/utils/EnvRunner.py in train(self, agent, episodes, max_len, description_configs, early_stop, stop_criteria, plot, train_episodal)
#      40                 observation = next_obs
#      41             if train_episodal:
# ---> 42                 agent.episodal_train_iter(policy)
#      43             agent.record_stats(end,episode,rewards)
#      44             description, avg = agent.get_description(episode,description_configs)
#
# ...

# %%
e.test(rtf)

# %% [markdown]
# ### Torch

# %%
rtorch = REINFORCETorch(learning_rate=0.0001,featurizer=None,scaler=None)

# %%
stats = e.train(rtorch,episodes=2500,train_episodal=True)

# %%
e.test(rtorch)
